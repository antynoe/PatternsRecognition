# %%
#from PIL import Image
from skimage import io, transform
from matplotlib import pyplot

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

# loading image from local memory
image = io.imread("C:/Users/Lenovo/Documents/GitHub/Patterns_database/dots/dot1.jpg")

# %%
pyplot.imshow(image)

# %%
t_image = torch.tensor(image)
pyplot.imshow(t_image)
print(t_image.shape)
# Out:
# torch.Size([300, 300, 3])

# %%
tv_image = t_image.view(1,3,300,300)

# %%
tv_image.shape
# Out:
# torch.Size([1, 3, 300, 300])

# %%
pyplot.imshow(tv_image[0][2])

# %%
# includes
from PIL import Image
from skimage import io, transform

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision as tv
import torch.optim as optim

# %%
# constansts

project_path = "/home/krys/POLIBUDA/Patterns_database/"


dots_path = project_path + "dots/dot"
paisley_path = project_path + "paisley/paisley"
qua_path = project_path + "quaterfoil/qua"
square_path = project_path + "squares/sq"
strips_path = project_path + "strips/pas"
traingles_path = project_path + "triangles/tr"

dots_target = torch.tensor([[float(1), float(0), float(0), float(0), float(0), float(0)]])
paisley_target = torch.tensor([[float(0), float(1), float(0), float(0), float(0), float(0)]])
qua_target = torch.tensor([[float(0), float(0), float(1), float(0), float(0), float(0)]])
square_target = torch.tensor([[float(0), float(0), float(0), float(1), float(0), float(0)]])
strips_target = torch.tensor([[float(0), float(0), float(0), float(0), float(1), float(0)]])
traingles_target = torch.tensor([[float(0), float(0), float(0), float(0), float(0), float(1)]])

paths = [
    dots_path,
    paisley_path,
    qua_path,
    square_path,
    strips_path,
    traingles_path
]

targets = [
    dots_target,
    paisley_target,
    qua_target,
    square_target,
    strips_target,
    traingles_target
]


def getImageTensor(path, idx):
    
    # loading image from local memory
    
    i_path = path + str(idx) + ".jpg"
    image = io.imread(i_path)
    
    return image
    

# transforms image to grayscale tensor
def myTransform(image):

    transformedImage =  tv.transforms.Compose([
                        tv.transforms.ToPILImage(),
                        tv.transforms.Grayscale(num_output_channels=1),
                        tv.transforms.ToTensor()
                      ])(image)
    
    transformedImage = transformedImage[0]

    return transformedImage

# %%
# includes
from PIL import Image
from skimage import io, transform

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision as tv
import torch.optim as optim

# nn model using pytorch schematic
class PatternRecognitionNet(nn.Module):

    def __init__(self):
        super(PatternRecognitionNet, self).__init__()

        self.conv1 = nn.Conv2d(1, 6, 3)
        self.conv2 = nn.Conv2d(6, 16, 3)
        self.fc1 = nn.Linear(16 * 73 * 73, 120) 
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 6)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), (2, 2))
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        x = x.view(-1, self.num_flat_features(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

    def num_flat_features(self, x):
        size = x.size()[1:]
        num_features = 1
        for s in size:
            num_features *= s
        return num_features

# %%
# creting net, lossfunction, optimizer    
pattNet = PatternRecognitionNet()
criterion = nn.MSELoss()
optimizer = optim.SGD(pattNet.parameters(), lr=0.3) # check learning rate

# %%
# training function
def train(image, target):
    
    optimizer.zero_grad()   # zero the gradient buffers
    input = image.view(-1,1,300,300)
    output = pattNet(input)
    print("Target: ",target)
    print("Output: ",output)
    loss = criterion(output, target)
    print("Loss calculation: " , loss)
    loss.backward()
    optimizer.step()    # Does the update

# %%
idx = 1
error_count = 0
while(1):
    try:
        
        for k in range(len(paths)):    
            print("============================================================\n")
            print("Training : " + str(idx) + " : " + str(k+1) + "/6")
            print("Path: " + paths[k])
            print("\n")
            image = getImageTensor(paths[k], idx)
            t_image = myTransform(image)
            train(t_image, targets[k])
            print("\n")
        
    except Exception as e:
        print("*******************************************************\n")
        print(e)
        print("\n")
        print("*******************************************************")
        
        error_count = error_count + 1
        
        if error_count > 2:    
            break 
        
    finally:
        idx = idx + 1
# Out:
# ============================================================
#
# Training : 1 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[-0.0677,  0.0773, -0.0754,  0.0196,  0.0348, -0.1017]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1939, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[ 0.0345,  0.0970, -0.0274, -0.0060,  0.0057, -0.0902]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1376, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[ 0.0279,  0.1759, -0.0432, -0.0077, -0.0100, -0.0599]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1873, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[ 0.0418,  0.1460,  0.0260, -0.0164, -0.0113, -0.0411]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1764, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[ 0.0165,  0.1447,  0.0153,  0.0547, -0.0175, -0.0325]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1768, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[-0.0032,  0.1093, -0.0056,  0.0399,  0.0688, -0.0657]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1923, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 2 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[-0.0080,  0.1081,  0.0010,  0.0382,  0.0569,  0.0172]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1721, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 2 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.0387, 0.1118, 0.0086, 0.0264, 0.0509, 0.0162]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1323, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 2 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.0666, 0.1842, 0.0301, 0.0373, 0.0227, 0.0560]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1640, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 2 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.0697, 0.1555, 0.0795, 0.0256, 0.0145, 0.0381]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1644, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 2 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.0373, 0.1584, 0.0737, 0.0916, 0.0053, 0.0373]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1719, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 2 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.0173, 0.1191, 0.0306, 0.0627, 0.0781, 0.0019]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1703, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 3 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.0490, 0.1388, 0.0776, 0.0837, 0.0612, 0.1097]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1587, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 3 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.1161, 0.1322, 0.0761, 0.0449, 0.0443, 0.0804]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1305, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 3 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.0895, 0.1848, 0.0627, 0.0571, 0.0348, 0.0677]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1550, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 3 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1145, 0.1830, 0.1305, 0.0543, 0.0136, 0.0825]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1608, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 3 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.0818, 0.1826, 0.1240, 0.1194, 0.0076, 0.0742]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1767, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 3 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.0415, 0.1334, 0.0666, 0.0913, 0.0881, 0.0285]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1640, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 4 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.0984, 0.1693, 0.1384, 0.1189, 0.0744, 0.1559]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1508, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 4 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.1703, 0.1449, 0.1285, 0.0766, 0.0663, 0.1249]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1338, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 4 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1275, 0.1997, 0.0954, 0.0757, 0.0536, 0.0953]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1487, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 4 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1414, 0.1892, 0.1542, 0.0709, 0.0429, 0.0900]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1588, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 4 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1102, 0.1848, 0.1375, 0.1366, 0.0373, 0.0871]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1697, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 4 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.0757, 0.1426, 0.0905, 0.1084, 0.1081, 0.0506]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1599, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 5 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.1758, 0.2099, 0.2118, 0.1689, 0.1128, 0.2408]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1446, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 5 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.1889, 0.1373, 0.1197, 0.0879, 0.0818, 0.1061]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1367, grad_fn=<MseLossBackward>)
# ============================================================
#
# Training : 5 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1525, 0.1951, 0.0973, 0.0891, 0.0694, 0.0954]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1497, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 5 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1332, 0.1674, 0.1251, 0.0755, 0.0647, 0.0659]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1541, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 5 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1250, 0.1665, 0.1258, 0.1292, 0.0559, 0.0729]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1621, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 5 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1409, 0.1619, 0.1363, 0.1292, 0.1163, 0.0856]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1552, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 6 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.1531, 0.1674, 0.1416, 0.1300, 0.1149, 0.1783]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1379, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 6 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.2130, 0.1494, 0.1371, 0.0951, 0.1050, 0.1567]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1387, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 6 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1392, 0.1856, 0.0810, 0.0865, 0.0892, 0.0976]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1539, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 6 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.2763, 0.2312, 0.2456, 0.1146, 0.0580, 0.2066]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1700, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 6 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1067, 0.1563, 0.1201, 0.1549, 0.0724, 0.0795]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1568, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 6 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.0930, 0.1388, 0.0987, 0.1374, 0.1325, 0.0664]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1576, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 7 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.1089, 0.1483, 0.1135, 0.1508, 0.1290, 0.1409]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1480, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 7 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.1893, 0.1452, 0.1326, 0.1295, 0.1131, 0.1478]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1392, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 7 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1199, 0.1698, 0.0790, 0.1094, 0.0997, 0.0866]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1535, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 7 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1693, 0.1870, 0.1557, 0.1220, 0.0868, 0.1253]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1470, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 7 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1288, 0.1748, 0.1323, 0.1709, 0.0799, 0.1034]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1585, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 7 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.0496, 0.1161, 0.0547, 0.1098, 0.1278, 0.0295]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1649, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 8 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.0802, 0.1300, 0.0850, 0.1258, 0.1310, 0.0881]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1518, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 8 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.2115, 0.1628, 0.1628, 0.1622, 0.1379, 0.1747]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1413, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 8 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1386, 0.2043, 0.0994, 0.1314, 0.1109, 0.1116]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1523, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 8 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1269, 0.1798, 0.1295, 0.1158, 0.1013, 0.0887]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1442, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 8 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1359, 0.1921, 0.1453, 0.1758, 0.0914, 0.1020]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1572, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 8 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1013, 0.1541, 0.1105, 0.1429, 0.1454, 0.0741]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1575, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 9 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.0858, 0.1427, 0.0878, 0.1273, 0.1384, 0.0968]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1514, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 9 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.1815, 0.1645, 0.1433, 0.1471, 0.1424, 0.1566]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1363, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 9 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1658, 0.2204, 0.1293, 0.1457, 0.1279, 0.1478]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1489, grad_fn=<MseLossBackward>)
# ============================================================
#
# Training : 9 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1605, 0.1991, 0.1731, 0.1339, 0.1160, 0.1290]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1459, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 9 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1344, 0.1907, 0.1590, 0.1859, 0.1045, 0.1173]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1550, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 9 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1209, 0.1680, 0.1400, 0.1656, 0.1636, 0.1045]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1531, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 10 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.1405, 0.1755, 0.1545, 0.1721, 0.1666, 0.1784]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1471, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 10 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.2221, 0.1700, 0.1748, 0.1568, 0.1570, 0.1903]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1424, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 10 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1590, 0.2097, 0.1225, 0.1355, 0.1309, 0.1374]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1489, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 10 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1352, 0.1798, 0.1417, 0.1172, 0.1173, 0.1025]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1457, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 10 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1312, 0.1823, 0.1471, 0.1668, 0.1121, 0.1100]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1501, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 10 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1400, 0.1759, 0.1522, 0.1659, 0.1687, 0.1213]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1503, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 11 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.1365, 0.1735, 0.1467, 0.1604, 0.1615, 0.1751]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1466, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 11 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.1759, 0.1575, 0.1396, 0.1350, 0.1477, 0.1542]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1373, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 11 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1513, 0.1935, 0.1184, 0.1308, 0.1281, 0.1311]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1480, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 11 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1055, 0.1572, 0.1104, 0.1076, 0.1172, 0.0821]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1441, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 11 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1307, 0.1744, 0.1403, 0.1541, 0.1133, 0.1120]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1483, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 11 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1529, 0.1779, 0.1584, 0.1586, 0.1658, 0.1372]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1462, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 12 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.1615, 0.1756, 0.1640, 0.1552, 0.1651, 0.1960]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1418, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 12 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.2010, 0.1614, 0.1552, 0.1309, 0.1514, 0.1762]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1398, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 12 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1727, 0.2043, 0.1295, 0.1279, 0.1357, 0.1522]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1479, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 12 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1593, 0.1811, 0.1581, 0.1187, 0.1228, 0.1334]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1488, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 12 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1363, 0.1734, 0.1448, 0.1567, 0.1148, 0.1176]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1486, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 12 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1574, 0.1763, 0.1628, 0.1616, 0.1656, 0.1449]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1445, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 13 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.0943, 0.1367, 0.0969, 0.1267, 0.1486, 0.1125]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1499, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 13 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.2283, 0.1805, 0.1905, 0.1553, 0.1615, 0.2188]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1430, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 13 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1442, 0.1976, 0.1145, 0.1282, 0.1359, 0.1397]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1497, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 13 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1742, 0.2039, 0.1798, 0.1347, 0.1261, 0.1609]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1491, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 13 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1232, 0.1777, 0.1404, 0.1640, 0.1151, 0.1174]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1484, grad_fn=<MseLossBackward>)
# ============================================================
#
# Training : 13 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.0834, 0.1430, 0.0986, 0.1355, 0.1494, 0.0777]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1547, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 14 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.1566, 0.1876, 0.1687, 0.1741, 0.1641, 0.1908]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1448, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 14 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.2053, 0.1753, 0.1645, 0.1518, 0.1552, 0.1808]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1382, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 14 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1062, 0.1641, 0.0821, 0.1141, 0.1293, 0.0885]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1530, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 14 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1797, 0.2054, 0.1740, 0.1412, 0.1300, 0.1530]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1471, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 14 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1568, 0.1974, 0.1645, 0.1865, 0.1198, 0.1403]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1533, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 14 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1302, 0.1693, 0.1335, 0.1628, 0.1679, 0.1201]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1487, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 15 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.1583, 0.1825, 0.1567, 0.1715, 0.1759, 0.1884]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1437, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 15 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.2060, 0.1719, 0.1556, 0.1511, 0.1615, 0.1765]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1387, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 15 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1665, 0.2044, 0.1211, 0.1357, 0.1426, 0.1431]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1502, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 15 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1711, 0.1899, 0.1756, 0.1369, 0.1323, 0.1420]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1465, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 15 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1461, 0.1778, 0.1598, 0.1743, 0.1256, 0.1251]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1482, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 15 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1521, 0.1759, 0.1615, 0.1755, 0.1748, 0.1351]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1483, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 16 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.1021, 0.1422, 0.1071, 0.1393, 0.1574, 0.1249]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1496, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 16 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.1741, 0.1593, 0.1402, 0.1450, 0.1591, 0.1592]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1381, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 16 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1144, 0.1647, 0.0876, 0.1220, 0.1389, 0.0988]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1528, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 16 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1415, 0.1766, 0.1391, 0.1307, 0.1357, 0.1251]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1434, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 16 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1258, 0.1744, 0.1323, 0.1656, 0.1277, 0.1179]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1443, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 16 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1619, 0.1879, 0.1600, 0.1797, 0.1768, 0.1562]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1438, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 17 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.0901, 0.1369, 0.0943, 0.1322, 0.1488, 0.1121]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1513, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 17 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.2012, 0.1746, 0.1599, 0.1569, 0.1684, 0.1964]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1398, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 17 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1854, 0.2214, 0.1465, 0.1535, 0.1537, 0.1896]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1492, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 17 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1336, 0.1716, 0.1400, 0.1268, 0.1349, 0.1219]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1437, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 17 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1560, 0.1974, 0.1753, 0.1863, 0.1316, 0.1605]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1514, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 17 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1355, 0.1673, 0.1465, 0.1612, 0.1790, 0.1393]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1444, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 18 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.1355, 0.1694, 0.1454, 0.1592, 0.1760, 0.1827]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1478, grad_fn=<MseLossBackward>)
# ============================================================
#
# Training : 18 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.2036, 0.1742, 0.1646, 0.1532, 0.1747, 0.2052]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1411, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 18 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1101, 0.1667, 0.0882, 0.1208, 0.1382, 0.1067]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1527, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 18 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1708, 0.2002, 0.1659, 0.1402, 0.1465, 0.1650]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1475, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 18 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1275, 0.1744, 0.1364, 0.1658, 0.1319, 0.1266]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1437, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 18 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1212, 0.1644, 0.1304, 0.1581, 0.1689, 0.1271]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1457, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 19 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.0895, 0.1373, 0.0986, 0.1345, 0.1537, 0.1166]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1522, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 19 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.1843, 0.1769, 0.1520, 0.1607, 0.1695, 0.1901]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1376, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 19 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1537, 0.1962, 0.1287, 0.1452, 0.1451, 0.1497]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1477, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 19 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1012, 0.1517, 0.1081, 0.1200, 0.1293, 0.0909]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1407, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 19 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1430, 0.1892, 0.1562, 0.1710, 0.1365, 0.1448]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1461, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 19 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1356, 0.1783, 0.1449, 0.1614, 0.1765, 0.1419]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1441, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 20 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.1107, 0.1539, 0.1193, 0.1409, 0.1627, 0.1436]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1493, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 20 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.2083, 0.1886, 0.1749, 0.1607, 0.1800, 0.2157]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1395, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 20 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1426, 0.1930, 0.1185, 0.1351, 0.1501, 0.1453]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1494, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 20 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1436, 0.1886, 0.1522, 0.1354, 0.1410, 0.1418]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1445, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 20 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1160, 0.1697, 0.1284, 0.1580, 0.1288, 0.1121]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1425, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 20 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1394, 0.1850, 0.1503, 0.1665, 0.1715, 0.1475]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1433, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 21 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.1252, 0.1713, 0.1360, 0.1537, 0.1676, 0.1688]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1489, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 21 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.2332, 0.2162, 0.1954, 0.1765, 0.1790, 0.2463]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1385, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 21 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1538, 0.2108, 0.1278, 0.1409, 0.1469, 0.1568]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1491, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 21 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1158, 0.1681, 0.1260, 0.1230, 0.1313, 0.1087]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1426, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 21 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1268, 0.1824, 0.1424, 0.1593, 0.1292, 0.1259]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1449, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 21 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1453, 0.1931, 0.1575, 0.1643, 0.1719, 0.1547]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1424, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 22 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.1172, 0.1660, 0.1297, 0.1445, 0.1597, 0.1550]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1490, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 22 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.1942, 0.1922, 0.1670, 0.1524, 0.1665, 0.2022]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1350, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 22 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1586, 0.2072, 0.1367, 0.1390, 0.1474, 0.1619]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1468, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 22 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1663, 0.2072, 0.1769, 0.1384, 0.1422, 0.1685]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1488, grad_fn=<MseLossBackward>)
# ============================================================
#
# Training : 22 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1533, 0.2065, 0.1738, 0.1819, 0.1333, 0.1627]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1512, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 22 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1097, 0.1631, 0.1239, 0.1500, 0.1629, 0.1132]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1482, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 23 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.1301, 0.1755, 0.1439, 0.1557, 0.1724, 0.1710]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1486, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 23 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[0.1868, 0.1841, 0.1606, 0.1528, 0.1691, 0.1874]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1356, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 23 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[0.1697, 0.2187, 0.1439, 0.1484, 0.1562, 0.1726]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1476, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 23 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[0.1581, 0.1947, 0.1710, 0.1371, 0.1455, 0.1536]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1469, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 23 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[0.1349, 0.1833, 0.1563, 0.1690, 0.1361, 0.1355]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1449, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 23 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1230, 0.1694, 0.1402, 0.1578, 0.1684, 0.1251]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1470, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# ...
#
#
# ============================================================
#
# Training : 1160 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[ 0.6636,  0.0019,  0.0587,  0.1213,  0.1754, -0.0230]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0271, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1160 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[ 0.0310,  0.9807,  0.0076, -0.0444,  0.0571, -0.0639]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0018, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1160 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[ 0.0907,  0.1446,  0.4265, -0.0103,  0.2888,  0.0691]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0744, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1160 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[-0.0829,  0.0475,  0.0294,  0.9666,  0.0314,  0.0817]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0031, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1160 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[-0.0858, -0.0793,  0.4480,  0.0511,  0.6267,  0.0550]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0599, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1160 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[-6.8662e-02, -2.0975e-04, -9.3963e-02, -3.3263e-02,  1.7097e-01,
#           9.4427e-01]], grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0078, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1161 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[ 0.9388, -0.0695, -0.0354,  0.0372,  0.0389,  0.1311]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0050, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1161 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[ 0.0436,  0.9504, -0.0081, -0.0625,  0.0124,  0.0257]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0015, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1161 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[-0.0044, -0.0353,  1.0741,  0.0035, -0.0397, -0.0697]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0022, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1161 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[ 0.0399,  0.0247, -0.0308,  0.8115,  0.1356,  0.0736]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0104, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1161 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[ 0.0631,  0.0740, -0.0534, -0.0394,  0.9750, -0.0939]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0039, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1161 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[ 0.0105, -0.0546, -0.1399, -0.0429, -0.0760,  1.3018]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0202, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1162 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[ 1.0554, -0.0241, -0.0690,  0.1235, -0.0181, -0.0899]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0053, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1162 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[-0.0342,  0.9459,  0.0445,  0.0803, -0.0539, -0.0677]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0033, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1162 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[ 0.0020,  0.0265,  1.0687, -0.0300, -0.0081, -0.0836]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0022, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1162 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[-0.0388,  0.0033, -0.0484,  1.0495,  0.0015,  0.0032]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0011, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1162 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[ 0.2847,  0.0668,  0.0326,  0.2170,  0.3694, -0.0040]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0886, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1162 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[0.1513, 0.0687, 0.0358, 0.0765, 0.2147, 0.4018]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0731, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1163 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[ 1.0839, -0.0374, -0.0099, -0.0355, -0.0522,  0.0910]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0035, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1163 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[-0.0569,  1.3393, -0.0394, -0.0569, -0.1071, -0.0412]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0227, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1163 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[ 0.0444, -0.0938,  0.9093,  0.1039,  0.0243, -0.0468]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0054, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1163 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[ 0.0893, -0.0109,  0.1903,  0.4157,  0.2569,  0.1256]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0779, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1163 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[ 0.0418, -0.0042, -0.0098, -0.0159,  0.9193,  0.0507]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0019, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1163 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[ 0.0446, -0.0413, -0.0022, -0.0059,  0.0720,  0.9493]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0019, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1164 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[ 0.9922, -0.0018,  0.0355,  0.0158,  0.0267, -0.0786]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0014, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1164 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[-0.0206,  0.8594, -0.0527,  0.0009,  0.0672,  0.0302]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0047, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1164 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[ 0.0140, -0.0070,  0.8016,  0.1046,  0.0228,  0.1484]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0122, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1164 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[ 0.1203, -0.0112,  0.2496,  0.2856,  0.2743,  0.1588]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.1146, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1164 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[-0.0158, -0.0376, -0.0273,  0.0211,  1.1950, -0.0511]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0073, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1164 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[-2.5479e-02, -3.6076e-02, -2.7553e-04,  1.1155e-01,  2.6683e-02,
#           9.2833e-01]], grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0034, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1165 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[ 0.8027, -0.0450, -0.0282,  0.1625,  0.0469,  0.0377]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0120, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1165 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[-0.0535,  0.9043,  0.0206,  0.1277,  0.0085, -0.0091]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0048, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1165 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[-0.0078,  0.0215,  0.9751,  0.0798, -0.0516, -0.0470]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0021, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1165 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[-4.8646e-02, -5.4985e-02,  1.0258e-01,  1.0258e+00,  9.0753e-04,
#           1.7467e-02]], grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0028, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1165 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[ 0.0217,  0.0035,  0.0529,  0.0245,  0.9845, -0.0408]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0010, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1165 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[ 0.0322, -0.0078, -0.0111,  0.0763,  0.0664,  0.8468]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0058, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1166 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# Target:  tensor([[1., 0., 0., 0., 0., 0.]])
# Output:  tensor([[0.7439, 0.0486, 0.0822, 0.0455, 0.0341, 0.0595]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0136, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1166 : 2/6
# Path: /home/krys/POLIBUDA/Patterns_database/paisley/paisley
#
#
# Target:  tensor([[0., 1., 0., 0., 0., 0.]])
# Output:  tensor([[-0.0306,  1.1407,  0.0538,  0.0037, -0.1078,  0.0081]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0059, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1166 : 3/6
# Path: /home/krys/POLIBUDA/Patterns_database/quaterfoil/qua
#
#
# Target:  tensor([[0., 0., 1., 0., 0., 0.]])
# Output:  tensor([[-0.0547,  0.0312,  0.9601, -0.0020,  0.0060,  0.0532]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0014, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1166 : 4/6
# Path: /home/krys/POLIBUDA/Patterns_database/squares/sq
#
#
# Target:  tensor([[0., 0., 0., 1., 0., 0.]])
# Output:  tensor([[ 0.0893, -0.0061,  0.0117,  0.8701,  0.0262,  0.0870]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0055, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1166 : 5/6
# Path: /home/krys/POLIBUDA/Patterns_database/strips/pas
#
#
# Target:  tensor([[0., 0., 0., 0., 1., 0.]])
# Output:  tensor([[-0.1604, -0.0518,  0.1518,  0.2414,  0.7916,  0.0488]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0259, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1166 : 6/6
# Path: /home/krys/POLIBUDA/Patterns_database/triangles/tr
#
#
# Target:  tensor([[0., 0., 0., 0., 0., 1.]])
# Output:  tensor([[-0.0067, -0.0828, -0.1317,  0.0686,  0.0573,  1.0877]],
#        grad_fn=<AddmmBackward>)
# Loss calculation:  tensor(0.0067, grad_fn=<MseLossBackward>)
#
#
# ============================================================
#
# Training : 1167 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# *******************************************************
#
# No such file: '/home/krys/POLIBUDA/Patterns_database/dots/dot1167.jpg'
#
#
# *******************************************************
# ============================================================
#
# Training : 1168 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# *******************************************************
#
# No such file: '/home/krys/POLIBUDA/Patterns_database/dots/dot1168.jpg'
#
#
# *******************************************************
# ============================================================
#
# Training : 1169 : 1/6
# Path: /home/krys/POLIBUDA/Patterns_database/dots/dot
#
#
# *******************************************************
#
# No such file: '/home/krys/POLIBUDA/Patterns_database/dots/dot1169.jpg'
#
#
# *******************************************************

# %%
PATH = project_path + "/modelV3.pt"
torch.save(pattNet.state_dict(), PATH)
